# %%
import requests

# %%
import bs4

# %%
result = requests.get("https://in.search.yahoo.com/search?fr=mcafee&type=E211IN826G0&p=jonas+salk+wikipedia")

# %%
type(result)
# Out:
# requests.models.Response

# %%
result.text
# Out:
# '<!doctype html><html id="atomic" class="NoJs" lang="en-IN"><head><meta http-equiv="x-dns-prefetch-control" content="on"><meta http-equiv="content-type" content="text/html; charset=UTF-8"><link rel="apple-touch-icon" sizes="76x76" href="https://s.yimg.com/pv/static/img/y_icon_iphone_76.min.png" /><link rel="apple-touch-icon" sizes="114x114" href="https://s.yimg.com/pv/static/img/y_icon_iphone_114.min.png" /><link rel="apple-touch-icon" sizes="120x120" href="https://s.yimg.com/pv/static/img/y_icon_iphone_120.min.png" /><meta name="referrer" content="origin"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta name="oath:guce:consent-host" content="guce.yahoo.com"/><noscript><meta http-equiv="refresh" content="0;url=https://in.search.yahoo.com/search?p=jonas+salk+wikipedia&type=E211IN826G0&ei=UTF-8&nojs=1"></noscript><script type="text/javascript">Array.prototype.indexOf||(Array.prototype.indexOf=function(r,t){"use strict";var e;if(null==this)throw new TypeError(
# ...

# %%
soup = bs4.BeautifulSoup(result.text,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.select('p')[0].getText()
# Out:
# 'Jonas Salk. Jonas Edward Salk ( / sɔːlk /; born Jonas Salk; October 28, 1914 – June 23, 1995) was an American virologist and medical researcher who developed one of the first successful polio vaccines. He was born in New York City and attended the City College of New York and New York University School of Medicine. '

# %%
soup.select('p')
# Out:
# [<p class="fz-14 lh-22 mah-44 ov-h d-box fbox-ov fbox-lc2"><span class="fc-falcon"><b>Jonas Salk</b>. <b>Jonas</b> Edward <b>Salk</b> ( / sɔːlk /; born <b>Jonas Salk</b>; October 28, 1914 – June 23, 1995) was an American virologist and medical researcher who developed one of the first successful polio vaccines. He was born in New York City and attended the City College of New York and New York University School of Medicine.</span> </p>,
#  <p class=""><span class="p-abs l-0 bgc-dirtyseagull bd-0 h-1 mt-18 w-100p"></span><a class="fz-14 lh-18 w-300 h-36 bxz-bb pt-8 pb-8 bd-1-E0E4E9 bdr-18 bgc-4th bgc-h-marshmallow p-rel d-ib" data-fa5="63f71405a20b1" href="https://in.images.search.yahoo.com/search/images?p=jonas+salk+wikipedia&amp;fr=mcafee" referrerpolicy="unsafe-url" style="text-decoration: none!important;" target="_blank"><span class="ico ico-modern arrow-right-blue d-b p-abs t-11 l-15"></span>View all</a> </p>,
# ...

# %%
soup.select('p')[0]
# Out:
# <p class="fz-14 lh-22 mah-44 ov-h d-box fbox-ov fbox-lc2"><span class="fc-falcon"><b>Jonas Salk</b>. <b>Jonas</b> Edward <b>Salk</b> ( / sɔːlk /; born <b>Jonas Salk</b>; October 28, 1914 – June 23, 1995) was an American virologist and medical researcher who developed one of the first successful polio vaccines. He was born in New York City and attended the City College of New York and New York University School of Medicine.</span> </p>

# %%
site_paragraphs = soup.select("p")

# %%
type(site_paragraphs[0])
# Out:
# bs4.element.Tag

# %%
result1 = requests.get("https://www.apple.com/in/")

# %%
result1.text
# Out:
# '\n\t\n\n\n\t\n\n\t\n\n\n\t\n\n\n\t\n\n\t\n\t\t\n\t\n\n\t\n\n\t\t\n\t\t\n\n\t\n\n\n\t\n\n\n\t\t\t\t\t\n\t\t\t\t\t\t\n<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en-IN" lang="en-IN" prefix="og: http://ogp.me/ns#" class="no-js" data-layout-name="evergreen">\n\n<head>\n    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<meta charset="utf-8" />\n<link rel="canonical" href="https://www.apple.com/in/" />\n\n\n\t\n\t<link rel="alternate" href="https://www.apple.com/" hreflang="en-US" /><link rel="alternate" href="https://www.apple.com/ae-ar/" hreflang="ar-AE" /><link rel="alternate" href="https://www.apple.com/ae/" hreflang="en-AE" /><link rel="alternate" href="https://www.apple.com/am/" hreflang="en-AM" /><link rel="alternate" href="https://www.apple.com/at/" hreflang="de-AT" /><link rel="alternate" href="https://www.apple.com/au/" hreflang="en-AU" /><link rel="alternate" href="https://www.apple.com/az/" hreflang="en-AZ" /><link rel="alternate" 
# ...

# %%
soup1 = bs4.BeautifulSoup(result1.text,"lxml")

# %%
soup1
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-layout-name="evergreen" lang="en-IN" prefix="og: http://ogp.me/ns#" xml:lang="en-IN" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <link href="https://www.apple.com/in/" rel="canonical"/>
# ...

# %%
soup1.select('p')[0].getText()
# Out:
# 'With superfast 5G*'

# %%
sample_result = requests.get('https://www.realme.com/in/')

# %%
soup2 = bs4.BeautifulSoup(sample_result.text,'lxml')

# %%
soup2.select('h3')[0].getText()
# Out:
# '\n                    \n                    realme 10 Pro+ 5G\n                    \n                  '

# %%
sample_result1 = requests.get('https://aeon.co/essays')

# %%
soup3 = bs4.BeautifulSoup(sample_result1.text,"lxml")

# %%
soup3.select('p')[3].getText()
# Out:
# 'In order to understand and heal mental distress, we must see our minds as existing in relationships, not inside our heads'

# %%
scraping_website = requests.get("https://aeon.co/essays/how-the-interpersonal-model-explains-and-heals-mental-pain")

# %%
extract = bs4.BeautifulSoup(scraping_website.text,"lxml")

# %%
extract.select('p')[8].getText()
# Out:
# 'I’d already been deeply interested in the limitations of Western models of mind, especially in terms of the enduring influence of René Descartes’s dualism between mind and body, mind and world, which set the West into modernity in the 17th century. But this had been a very academic and abstract pursuit. In relational theory, however, I found not only the answers to the problems that our dualistic heritage bestowed upon us, but also to my own suffering, and the roots of much psychological and emotional distress in general.'

# %%
website_to_scrap = requests.get("https://www.bloomberg.com/asia")

# %%
extracted_content = bs4.BeautifulSoup(website_to_scrap.text,"lxml")

# %%
extracted_content.select('p')[0].getText()
# Out:
# "To continue, please click the box below to let us know you're not a robot."

# %%
website_name = requests.get("https://en.wikipedia.org/wiki/Grace_Hopper")

# %%
extracts = bs4.BeautifulSoup(website_name.text,"lxml")

# %%
# extracts

# %%
extracts.select('.vector-toc-text')
# Out:
# [<div class="vector-toc-text">(Top)</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">1</span>Early life and education</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">2</span>Career</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">2.1</span>World War II</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">2.2</span>UNIVAC</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">2.3</span>COBOL</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">2.4</span>Standards</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">3</span>Retirement</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">4</span>Post-retirement</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">5</span>Anecdotes</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">6</span>Death</div>,
# ...

# %%
first_item = extracts.select(".vector-toc-text")[0]

# %%
first_item.text
# Out:
# '(Top)'

# %%
for item in extracts.select(".vector-toc-text"):
    print(item.text)
# Out:
# (Top)
#
# 1Early life and education
#
# 2Career
#
# 2.1World War II
#
# 2.2UNIVAC
#
# 2.3COBOL
#
# 2.4Standards
#
# 3Retirement
#
# 4Post-retirement
#
# 5Anecdotes
#
# 6Death
#
# 7Dates of rank
#
# 8Awards and honors
#
# 8.1Military awards
#
# 8.2Other awards
#
# 9Legacy
#
# 9.1Places
#
# 9.2Programs
#
# 9.3In popular culture
#
# 9.3.1Grace Hopper Celebration of Women in Computing
#
# 10See also
#
# 11Notes
#
# 12Obituary notices
#
# 13References
#
# 14Further reading
#
# 15External links

# %%
website_name = requests.get("https://en.wikipedia.org/wiki/Banaras_Hindu_University")

# %%
extracts = bs4.BeautifulSoup(website_name.text,"lxml")

# %%
extracts.select(".vector-toc-text")
# Out:
# [<div class="vector-toc-text">(Top)</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">1</span>History</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">2</span>Campus</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">2.1</span>Main campus</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">2.2</span>Rajiv Gandhi South Campus</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">2.3</span>Halls of residence</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">3</span>Organisation and administration</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">3.1</span>Governance</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">3.2</span>University Temple</div>,
#  <div class="vector-toc-text">
#  <span class="vector-toc-numb">3.3</span>International Centre</div>,
#  <div class="vector-toc-text">
# ...

# %%
for item in extracts.select(".vector-toc-text"):
    print (item.text)
# Out:
# (Top)
#
# 1History
#
# 2Campus
#
# 2.1Main campus
#
# 2.2Rajiv Gandhi South Campus
#
# 2.3Halls of residence
#
# 3Organisation and administration
#
# 3.1Governance
#
# 3.2University Temple
#
# 3.3International Centre
#
# 3.4University Museum
#
# 3.5Banaras Hindu University Press
#
# 4Academics
#
# 4.1Institutes
#
# 4.2Faculties
#
# 4.2.1Faculty of Social Sciences (FSS)
#
# 4.3Colleges and schools
#
# 4.3.1Colleges
#
# 4.3.2Schools
#
# 4.4Inter-disciplinary schools
#
# 4.4.1School of Biotechnology
#
# 4.4.2DBT-BHU Interdisciplinary School of Life Sciences
#
# 4.5Research centres
#
# 4.5.1Other research centres
#
# 4.6Special centres
#
# 4.6.1Design Innovation Centre
#
# 4.6.2BioNest-BHU
#
# 4.7Admissions
#
# 4.7.1Banaras Hindu University Entrance Tests
#
# 4.8Rankings
#
# 4.9Library
#
# 5Student life
#
# 5.1Festivals and traditions
#
# 5.1.1Convocation Dress
#
# 5.2Clubs and societies
#
# 5.3Awards and medals
#
# 5.4Student unions and protests
#
# ...

# %%
website = requests.get("https://en.wikipedia.org/wiki/Banaras_Hindu_University")

# %%
type(website)
# Out:
# requests.models.Response

# %%
extract2 = bs4.BeautifulSoup(website.text,"lxml")

# %%
extract2.select(".infobox-label")
# Out:
# [<th class="infobox-label" scope="row" style="padding-right:0.65em;"><div style="display: inline-block; line-height: 1.2em; padding: .1em 0;">Other names</div></th>,
#  <th class="infobox-label" scope="row" style="padding-right:0.65em;"><div style="display: inline-block; line-height: 1.2em; padding: .1em 0;">Former name</div></th>,
#  <th class="infobox-label" scope="row" style="padding-right:0.65em;">Motto</th>,
#  <th class="infobox-label" scope="row" style="padding-right:0.65em;"><div style="display: inline-block; line-height: 1.2em; padding: .1em 0;">Motto in English</div></th>,
#  <th class="infobox-label" scope="row" style="padding-right:0.65em;">Type</th>,
#  <th class="infobox-label" scope="row" style="padding-right:0.65em;">Established</th>,
#  <th class="infobox-label" scope="row" style="padding-right:0.65em;">Founders</th>,
# ...

# %%
for items in extract2.select(".infobox-label"):
    print (items.text)
# Out:
# Other names
# Former name
# Motto
# Motto in English
# Type
# Established
# Founders
# Academic affiliations
# Budget
# Chancellor
# Vice-Chancellor
# Students
# Undergraduates
# Postgraduates
# Doctoral students
# Location
# Campus
# Language
# Anthem
# Colours
# Mascot
# Website
# Times (World) (2022)[207]
# Times (Asia) (2021)[208]
# Times (Emerging) (2021)[209]
# NIRF (Overall) (2022)[210]
# NIRF (Universities) (2022)[211]
# Outlook India (Universities) (2020)[212]
# NIRF (2022)[213]
# NIRF (2022)[214]
# India Today (2020)[215]
# NIRF (2022)[216]
# India Today (2020)[217]
# NIRF (2022)[218]

# %%
import bs4
import requests

# %%
website_name = requests.get("https://en.wikipedia.org/wiki/Deep_Blue_(chess_computer)")

# %%
soup = bs4.BeautifulSoup(website_name.text,"lxml")

# %%
soup.select("img")[3]
# Out:
# <img alt="This is a good article. Click here for more information." data-file-height="185" data-file-width="180" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/19px-Symbol_support_vote.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/29px-Symbol_support_vote.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/39px-Symbol_support_vote.svg.png 2x" width="19"/>

# %%
image_link = requests.get("https://upload.wikimedia.org/wikipedia/en/thumb/9/94/Symbol_support_vote.svg/19px-Symbol_support_vote.svg.png")

# %%
# image_link.content

# %%
f = open('my_computer_image.png','wb')

# %%
f.write(image_link.content)
# Out:
# 1166

# %%
f.close()

# %%
#Goal: Get title of every book with a 2 star rating

# %%
import requests

# %%
import bs4

# %%
"http://books.toscrape.com/catalogue/page-1.html"
"http://books.toscrape.com/catalogue/page-2.html"
"http://books.toscrape.com/catalogue/page-3.html"
# Out:
# 'http://books.toscrape.com/catalogue/page-3.html'

# %%
base_url = "http://books.toscrape.com/catalogue/page-{}.html"

# %%
base_url.format('20')
# Out:
# 'http://books.toscrape.com/catalogue/page-20.html'

# %%
page_num = 12
base_url.format(page_num)
# Out:
# 'http://books.toscrape.com/catalogue/page-12.html'
